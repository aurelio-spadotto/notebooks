# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
table = pd.read_csv("../various_data/new.csv",header=None,sep=';')
table = table.to_numpy()

# %%
fig,ax = plt.subplots()
ax.semilogx(table[:,0],table[:,1])
